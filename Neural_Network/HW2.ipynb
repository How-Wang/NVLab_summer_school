# %% [markdown]
# # Numpy neural network

# %%
import numpy as np
import gzip

# %% [markdown]
# ## 1. Unpackaged .gz file

# %%
url_train_image = "Fashion_MNIST_data/train-images-idx3-ubyte.gz"
url_train_labels = "Fashion_MNIST_data/train-labels-idx1-ubyte.gz"
url_test_image = "Fashion_MNIST_data/t10k-images-idx3-ubyte.gz"
url_test_labels = "Fashion_MNIST_data/t10k-labels-idx1-ubyte.gz"

# %%
def load_data():
    path_list = [url_train_image, url_train_labels, url_test_image, url_test_labels]
    with gzip.open(path_list[0], 'rb') as f:
        x_train = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)/255.0
    with gzip.open(path_list[1], 'rb') as f:
        y_train = np.frombuffer(f.read(), np.uint8, offset=8)
    with gzip.open(path_list[2], 'rb') as f:
        x_test = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)/255.0
    with gzip.open(path_list[3], 'rb') as f:
        y_test = np.frombuffer(f.read(), np.uint8, offset=8)
        
    return (x_train, y_train), (x_test, y_test)

# %%
(X_train, y_train), (x_test, y_test) = load_data()

# %%
print(y_test.shape)
# Out:
# (10000,)

# %% [markdown]
# ## 2. Define Model

# %%
class FFNN:
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        self.input_size = input_size
        self.hidden_size1 = hidden_size1
        self.hidden_size2 = hidden_size2
        self.output_size = output_size
        
        # Initialize weights and biases for the first hidden layer
        # self.W1 = np.random.randn(self.input_size, self.hidden_size1)
        # use normal distribution to initialize weights
        self.W1 = np.random.normal(0.0, pow(self.input_size, -0.5), (self.input_size, self.hidden_size1))
        self.b1 = np.zeros(self.hidden_size1)
        
        # Initialize weights and biases for the second hidden layer
        # self.W2 = np.random.randn(self.hidden_size1, self.hidden_size2)
        self.W2 = np.random.normal(0.0, pow(self.hidden_size1, -0.5), (self.hidden_size1, self.hidden_size2))
        self.b2 = np.zeros(self.hidden_size2)
        
        # Initialize weights and biases for the output layer
        # self.W3 = np.random.randn(self.hidden_size2, self.output_size)
        self.W3 = np.random.normal(0.0, pow(self.hidden_size2, -0.5), (self.hidden_size2, self.output_size))
        self.b3 = np.zeros(self.output_size)
        
        self.train_loss = []
        self.train_score = []
        self.test_loss = []
        self.test_score = []
        
    def forward(self, X):
        # Forward pass through the network
        
        ## Note: np.dot(X, self.W1) size is (N, hidden_size1),
        ## self.b1 size is (hidden_size1)
        ## so self.b1 will be broadcasted to the same shape as np.dot(X, self.W1)
        ## self.z1 size is (N, hidden_size1)
        
        self.z1 = np.dot(X, self.W1) + self.b1
        # self.a1 = self.relu(self.z1) 
        self.a1 = self.sigmoid(self.z1)
        
        self.z2 = np.dot(self.a1, self.W2) + self.b2
        # self.a2 = self.relu(self.z2)
        self.a2 = self.sigmoid(self.z2)
        
        self.z3 = np.dot(self.a2, self.W3) + self.b3
        self.a3 = self.softmax(self.z3)
        
        return self.a3
    
    def relu(self, x):
        ## Note: 0 will be broadcasted to the same shape as x is (N, hidden_size) 
        ## np.maximun is element-wise to compare which one is bigger 
        ## reture size is the same as x
        return np.maximum(0, x)
    
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def softmax(self, x):
        ## Note1: 
        ## x size is (N, output_size)
        ## we need to sum over the second dimension, so we set axis=1, size is (N, 1)
        ## and np.exp(x) size is (N, output_size)
        ## so np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True) size is (N, output_size)
        ## division here is broadcasted over the first dimension too
        
        # exp_x = np.exp(x)
        # return exp_x / np.sum(exp_x, axis=1, keepdims=True)
    
        ## Note2: 
        ## subtracting the maximum value along the axis
        ## is to prevent overflow when exponentiating large values
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)
    
    def cross_entropy_loss(self, y_ture, y_pred):
        ## Note 1:
        ## dividing by y_true.shape[0] (the number of samples in the batch) 
        ## is a normalization step to ensure that the loss is independent of the batch size.
        ## The loss function measures the average loss per sample in the batch.
        ## Note 2: 
        ## original y size is (N, 1), y_pred size is (N, output_size), 
        ## we need to change y to one-hot encoding.
        ## Note 3:
        ## np.sum(y_ture * np.log(y_pred)) at the beginning is nan
        ## because y_pred is nearly 0 at the beginning, and log(0) is not defined, so it is nan
        ## we need to add a small number to y_pred to avoid this problem
        epsilon = 1e-8
        return -np.sum(y_ture * np.log(y_pred + epsilon)) / y_ture.shape[0]
    
    def relu_derivative(self, x):
        return np.where(x > 0, 1, 0)
    
    def sigmoid_derivative(self, x):
        return self.sigmoid(x) * (1 - self.sigmoid(x))
    
    def backward(self, X, y_ture, lr=0.01):
        m = X.shape[0]
        
        # Output layer gradients
        ## Note: dL_dz3 is calculated by the derivative of cross entropy and softmax
        ## Note self.a3 size is (N, output_size), y_ture size is (N, output_size), dL_dz3 size is (N, output_size)
        dL_dz3 = (self.a3 - y_ture) / m
        ## Note: dL_dW3 is multiplied by backward and forward propagation
        ## self.a2.T size is (hidden_size2, N), dL_dz3 size is (N, output_size), dL_dW3 size is (hidden_size2, output_size)
        dL_dW3 = np.dot(self.a2.T, dL_dz3)
        dL_db3 = np.sum(dL_dz3, axis=0)
        
        # Hidden layer 2 gradients
        # self.W3.T size is (output_size, hidden_size2), dL_dz3 size is (N, output_size), dL_dz2 and self.z2 size is (N, hidden_size2)
        # dL_dz2 = np.dot(dL_dz3, self.W3.T) * self.relu_derivative(self.z2) / m
        dL_dz2 = np.dot(dL_dz3, self.W3.T) * self.sigmoid_derivative(self.z2) / m
        # self.a1.T size is (hidden_size1, N),  dL_dz2 size is (N, hidden_size2)
        dL_dW2 = np.dot(self.a1.T, dL_dz2)
        dL_db2 = np.sum(dL_dz2, axis=0)
        
        # Hidden layer 1 gradients
        # dL_dz1 = np.dot(dL_dz2, self.W2.T) * self.relu_derivative(self.z1) / m
        dL_dz1 = np.dot(dL_dz2, self.W2.T) * self.sigmoid_derivative(self.z1) / m
        dL_dW1 = np.dot(X.T, dL_dz1)
        dL_db1 = np.sum(dL_dz1, axis=0)
        
        # Update weights and biases
        self.W3 -= lr * dL_dW3
        self.b3 -= lr * dL_db3
        self.W2 -= lr * dL_dW2
        self.b2 -= lr * dL_db2
        self.W1 -= lr * dL_dW1
        self.b1 -= lr * dL_db1
    
    def precison(self, y_ture, y_pred):
        y_pred_labels = np.argmax(y_pred, axis=1)
        y_ture_labels = np.argmax(y_ture, axis=1)
        return np.sum(y_ture_labels == y_pred_labels) / len(y_ture)
        
    def train(self, X, y, x_test, y_test, epochs=100, lr=0.01, batch_size=32):
        for epoch in range(epochs):
            for i in range(0, X.shape[0], batch_size):
                X_batch = X[i:i+batch_size]
                y_batch = y[i:i+batch_size]
                
                y_pred = self.forward(X_batch)
                loss = self.cross_entropy_loss(y_batch, y_pred)
                score = self.precison(y_batch, y_pred)
                self.backward(X_batch, y_batch, lr)
                
            self.train_loss.append(loss)
            self.train_score.append(score)
            self.predict(x_test, y_test)
            
            if (epoch+1) % 10 == 0:
                print(f'Epoch {epoch+1}, \nTrain  loss {loss:.4f}, precision {score:.4f}')
        
        self.save_weights(f'Model/batch{batch_size}_epoch{epochs}_train{self.train_score[-1]}_test{self.test_score[-1]}_weights.npy')
            
        return self.train_loss, self.train_score, self.test_loss, self.test_score
                
                
    def predict(self, X, y):
        y_pred = self.forward(X)
        loss = self.cross_entropy_loss(y, y_pred)
        score = self.precison(y, y_pred)
        self.test_loss.append(loss)
        self.test_score.append(score)
        # print(f'Test Loss: {loss:.4f}, precision: {score:.4f}')
        
    def save_weights(self, file_path):
        # Save model weights to a .npy file
        weights = {
            "W1": self.W1,
            "b1": self.b1,
            "W2": self.W2,
            "b2": self.b2,
            "W3": self.W3,
            "b3": self.b3,
        }
        np.save(file_path, weights)

    def load_weights(self, file_path):
        # Load model weights from a .npy file
        weights = np.load(file_path, allow_pickle=True).item()
        self.W1 = weights["W1"]
        self.b1 = weights["b1"]
        self.W2 = weights["W2"]
        self.b2 = weights["b2"]
        self.W3 = weights["W3"]
        self.b3 = weights["b3"]

# %% [markdown]
# ## 3. Train Model

# %%
INPUT_SIZE = 784
HIDDEN_SIZE1 = 392
HIDDEN_SIZE2 = 128
OUTPUT_SIZE = 10

LEARNING_RATE = 0.1
EPOCHS = 3000
BATCH_SIZE = 100

y_train_onehot = np.eye(OUTPUT_SIZE)[y_train]
y_test_onehot = np.eye(OUTPUT_SIZE)[y_test]

nn = FFNN(INPUT_SIZE, HIDDEN_SIZE1, HIDDEN_SIZE2, OUTPUT_SIZE)
train_loss, train_score, test_loss, test_score = nn.train(X_train, y_train_onehot, x_test, y_test_onehot, EPOCHS, LEARNING_RATE, BATCH_SIZE)
# Out:
# Epoch 10,
# Train  loss 1.2882, precision 0.6400
# Epoch 20,
# Train  loss 0.9169, precision 0.6900
# Epoch 30,
# Train  loss 0.7708, precision 0.7400
# Epoch 40,
# Train  loss 0.6953, precision 0.7700
# Epoch 50,
# Train  loss 0.6475, precision 0.8000
# Epoch 60,
# Train  loss 0.6128, precision 0.8100
# Epoch 70,
# Train  loss 0.5857, precision 0.8100
# Epoch 80,
# Train  loss 0.5637, precision 0.8600
# Epoch 90,
# Train  loss 0.5456, precision 0.8500
# Epoch 100,
# Train  loss 0.5306, precision 0.8500
# Epoch 110,
# Train  loss 0.5181, precision 0.8500
# Epoch 120,
# Train  loss 0.5076, precision 0.8500
# Epoch 130,
# Train  loss 0.4987, precision 0.8500
# Epoch 140,
# Train  loss 0.4912, precision 0.8500
# Epoch 150,
# Train  loss 0.4847, precision 0.8500
# Epoch 160,
# Train  loss 0.4790, precision 0.8500
# Epoch 170,
# Train  loss 0.4740, precision 0.8500
# Epoch 180,
# Train  loss 0.4695, precision 0.8500
# Epoch 190,
# Train  loss 0.4654, precision 0.8500
# Epoch 200,
# Train  loss 0.4618, precision 0.8500
# Epoch 210,
# Train  loss 0.4584, precision 0.8500
# Epoch 220,
# Train  loss 0.4552, precision 0.8500
# Epoch 230,
# Train  loss 0.4523, precision 0.8500
# Epoch 240,
# Train  loss 0.4495, precision 0.8700
# Epoch 250,
# Train  loss 0.4468, precision 0.8700
# Epoch 260,
# Train  loss 0.4442, precision 0.8700
# Epoch 270,
# Train  loss 0.4417, precision 0.8700
# Epoch 280,
# Train  loss 0.4394, precision 0.8700
# Epoch 290,
# Train  loss 0.4370, precision 0.8700
# Epoch 300,
# Train  loss 0.4348, precision 0.8700
# Epoch 310,
# Train  loss 0.4326, precision 0.8700
# Epoch 320,
# Train  loss 0.4305, precision 0.8700
# Epoch 330,
# Train  loss 0.4284, precision 0.8700
# Epoch 340,
# Train  loss 0.4264, precision 0.8700
# Epoch 350,
# Train  loss 0.4244, precision 0.8600
# Epoch 360,
# Train  loss 0.4225, precision 0.8600
# Epoch 370,
# Train  loss 0.4206, precision 0.8600
# Epoch 380,
# Train  loss 0.4188, precision 0.8600
# Epoch 390,
# Train  loss 0.4170, precision 0.8600
# Epoch 400,
# Train  loss 0.4153, precision 0.8600
# Epoch 410,
# Train  loss 0.4136, precision 0.8600
# Epoch 420,
# Train  loss 0.4120, precision 0.8600
# Epoch 430,
# Train  loss 0.4104, precision 0.8600
# Epoch 440,
# Train  loss 0.4088, precision 0.8600
# Epoch 450,
# Train  loss 0.4073, precision 0.8600
# Epoch 460,
# Train  loss 0.4059, precision 0.8600
# Epoch 470,
# Train  loss 0.4044, precision 0.8600
# Epoch 480,
# Train  loss 0.4031, precision 0.8600
# Epoch 490,
# Train  loss 0.4017, precision 0.8600
# Epoch 500,
# Train  loss 0.4004, precision 0.8600
# Epoch 510,
# Train  loss 0.3991, precision 0.8600
# Epoch 520,
# Train  loss 0.3979, precision 0.8600
# Epoch 530,
# Train  loss 0.3967, precision 0.8600
# Epoch 540,
# Train  loss 0.3955, precision 0.8600
# Epoch 550,
# Train  loss 0.3944, precision 0.8600
# Epoch 560,
# Train  loss 0.3933, precision 0.8600
# Epoch 570,
# Train  loss 0.3922, precision 0.8600
# Epoch 580,
# Train  loss 0.3912, precision 0.8600
# Epoch 590,
# Train  loss 0.3902, precision 0.8600
# Epoch 600,
# Train  loss 0.3892, precision 0.8600
# Epoch 610,
# Train  loss 0.3883, precision 0.8600
# Epoch 620,
# Train  loss 0.3873, precision 0.8700
# Epoch 630,
# Train  loss 0.3864, precision 0.8700
# Epoch 640,
# Train  loss 0.3855, precision 0.8700
# Epoch 650,
# Train  loss 0.3847, precision 0.8700
# Epoch 660,
# Train  loss 0.3838, precision 0.8700
# Epoch 670,
# Train  loss 0.3830, precision 0.8700
# Epoch 680,
# Train  loss 0.3822, precision 0.8700
# Epoch 690,
# Train  loss 0.3814, precision 0.8700
# Epoch 700,
# Train  loss 0.3807, precision 0.8700
# Epoch 710,
# Train  loss 0.3799, precision 0.8700
# Epoch 720,
# Train  loss 0.3792, precision 0.8700
# Epoch 730,
# Train  loss 0.3785, precision 0.8700
# Epoch 740,
# Train  loss 0.3778, precision 0.8700
# Epoch 750,
# Train  loss 0.3771, precision 0.8700
# Epoch 760,
# Train  loss 0.3764, precision 0.8700
# Epoch 770,
# Train  loss 0.3758, precision 0.8700
# Epoch 780,
# Train  loss 0.3752, precision 0.8700
# Epoch 790,
# Train  loss 0.3745, precision 0.8700
# Epoch 800,
# Train  loss 0.3739, precision 0.8700
# Epoch 810,
# Train  loss 0.3733, precision 0.8700
# Epoch 820,
# Train  loss 0.3727, precision 0.8700
# Epoch 830,
# Train  loss 0.3721, precision 0.8700
# Epoch 840,
# Train  loss 0.3716, precision 0.8700
# Epoch 850,
# Train  loss 0.3710, precision 0.8700
# Epoch 860,
# Train  loss 0.3705, precision 0.8700
# Epoch 870,
# Train  loss 0.3699, precision 0.8700
# Epoch 880,
# Train  loss 0.3694, precision 0.8700
# Epoch 890,
# Train  loss 0.3689, precision 0.8700
# Epoch 900,
# Train  loss 0.3684, precision 0.8700
# Epoch 910,
# Train  loss 0.3679, precision 0.8700
# Epoch 920,
# Train  loss 0.3674, precision 0.8700
# Epoch 930,
# Train  loss 0.3669, precision 0.8700
# Epoch 940,
# Train  loss 0.3664, precision 0.8700
# Epoch 950,
# Train  loss 0.3659, precision 0.8700
# Epoch 960,
# Train  loss 0.3655, precision 0.8700
# Epoch 970,
# Train  loss 0.3650, precision 0.8700
# Epoch 980,
# Train  loss 0.3645, precision 0.8700
# Epoch 990,
# Train  loss 0.3641, precision 0.8700
# Epoch 1000,
# Train  loss 0.3636, precision 0.8700
# Epoch 1010,
# Train  loss 0.3632, precision 0.8700
# Epoch 1020,
# Train  loss 0.3628, precision 0.8700
# Epoch 1030,
# Train  loss 0.3623, precision 0.8700
# Epoch 1040,
# Train  loss 0.3619, precision 0.8700
# Epoch 1050,
# Train  loss 0.3615, precision 0.8700
# Epoch 1060,
# Train  loss 0.3611, precision 0.8700
# Epoch 1070,
# Train  loss 0.3607, precision 0.8700
# Epoch 1080,
# Train  loss 0.3603, precision 0.8700
# Epoch 1090,
# Train  loss 0.3599, precision 0.8700
# Epoch 1100,
# Train  loss 0.3595, precision 0.8700
# Epoch 1110,
# Train  loss 0.3591, precision 0.8700
# Epoch 1120,
# Train  loss 0.3587, precision 0.8700
# Epoch 1130,
# Train  loss 0.3583, precision 0.8700
# Epoch 1140,
# Train  loss 0.3579, precision 0.8700
# Epoch 1150,
# Train  loss 0.3575, precision 0.8700
# Epoch 1160,
# Train  loss 0.3572, precision 0.8700
# Epoch 1170,
# Train  loss 0.3568, precision 0.8700
# Epoch 1180,
# Train  loss 0.3564, precision 0.8700
# Epoch 1190,
# Train  loss 0.3560, precision 0.8700
# Epoch 1200,
# Train  loss 0.3557, precision 0.8700
# Epoch 1210,
# Train  loss 0.3553, precision 0.8700
# Epoch 1220,
# Train  loss 0.3550, precision 0.8700
# Epoch 1230,
# Train  loss 0.3546, precision 0.8700
# Epoch 1240,
# Train  loss 0.3542, precision 0.8700
# Epoch 1250,
# Train  loss 0.3539, precision 0.8700
# Epoch 1260,
# Train  loss 0.3535, precision 0.8700
# Epoch 1270,
# Train  loss 0.3532, precision 0.8700
# Epoch 1280,
# Train  loss 0.3528, precision 0.8700
# Epoch 1290,
# Train  loss 0.3525, precision 0.8700
# Epoch 1300,
# Train  loss 0.3521, precision 0.8700
# Epoch 1310,
# Train  loss 0.3518, precision 0.8700
# Epoch 1320,
# Train  loss 0.3515, precision 0.8700
# Epoch 1330,
# Train  loss 0.3511, precision 0.8700
# Epoch 1340,
# Train  loss 0.3508, precision 0.8700
# Epoch 1350,
# Train  loss 0.3504, precision 0.8700
# Epoch 1360,
# Train  loss 0.3501, precision 0.8700
# Epoch 1370,
# Train  loss 0.3498, precision 0.8700
# Epoch 1380,
# Train  loss 0.3494, precision 0.8700
# Epoch 1390,
# Train  loss 0.3491, precision 0.8700
# Epoch 1400,
# Train  loss 0.3488, precision 0.8700
# Epoch 1410,
# Train  loss 0.3484, precision 0.8700
# Epoch 1420,
# Train  loss 0.3481, precision 0.8700
# Epoch 1430,
# Train  loss 0.3478, precision 0.8700
# Epoch 1440,
# Train  loss 0.3475, precision 0.8700
# Epoch 1450,
# Train  loss 0.3471, precision 0.8700
# Epoch 1460,
# Train  loss 0.3468, precision 0.8700
# Epoch 1470,
# Train  loss 0.3465, precision 0.8700
# Epoch 1480,
# Train  loss 0.3461, precision 0.8700
# Epoch 1490,
# Train  loss 0.3458, precision 0.8700
# Epoch 1500,
# Train  loss 0.3455, precision 0.8700
# Epoch 1510,
# Train  loss 0.3452, precision 0.8700
# Epoch 1520,
# Train  loss 0.3449, precision 0.8700
# Epoch 1530,
# Train  loss 0.3445, precision 0.8700
# Epoch 1540,
# Train  loss 0.3442, precision 0.8700
# Epoch 1550,
# Train  loss 0.3439, precision 0.8700
# Epoch 1560,
# Train  loss 0.3436, precision 0.8700
# Epoch 1570,
# Train  loss 0.3432, precision 0.8700
# Epoch 1580,
# Train  loss 0.3429, precision 0.8700
# Epoch 1590,
# Train  loss 0.3426, precision 0.8700
# Epoch 1600,
# Train  loss 0.3423, precision 0.8700
# Epoch 1610,
# Train  loss 0.3420, precision 0.8700
# Epoch 1620,
# Train  loss 0.3416, precision 0.8700
# Epoch 1630,
# Train  loss 0.3413, precision 0.8700
# Epoch 1640,
# Train  loss 0.3410, precision 0.8700
# Epoch 1650,
# Train  loss 0.3407, precision 0.8700
# Epoch 1660,
# Train  loss 0.3404, precision 0.8700
# Epoch 1670,
# Train  loss 0.3401, precision 0.8700
# Epoch 1680,
# Train  loss 0.3397, precision 0.8700
# Epoch 1690,
# Train  loss 0.3394, precision 0.8700
# Epoch 1700,
# Train  loss 0.3391, precision 0.8700
# Epoch 1710,
# Train  loss 0.3388, precision 0.8700
# Epoch 1720,
# Train  loss 0.3385, precision 0.8800
# Epoch 1730,
# Train  loss 0.3381, precision 0.8800
# Epoch 1740,
# Train  loss 0.3378, precision 0.8800
# Epoch 1750,
# Train  loss 0.3375, precision 0.8700
# Epoch 1760,
# Train  loss 0.3372, precision 0.8700
# Epoch 1770,
# Train  loss 0.3369, precision 0.8700
# Epoch 1780,
# Train  loss 0.3365, precision 0.8700
# Epoch 1790,
# Train  loss 0.3362, precision 0.8700
# Epoch 1800,
# Train  loss 0.3359, precision 0.8700
# Epoch 1810,
# Train  loss 0.3356, precision 0.8700
# Epoch 1820,
# Train  loss 0.3353, precision 0.8700
# Epoch 1830,
# Train  loss 0.3350, precision 0.8700
# Epoch 1840,
# Train  loss 0.3346, precision 0.8700
# Epoch 1850,
# Train  loss 0.3343, precision 0.8700
# Epoch 1860,
# Train  loss 0.3340, precision 0.8700
# Epoch 1870,
# Train  loss 0.3337, precision 0.8700
# Epoch 1880,
# Train  loss 0.3334, precision 0.8800
# Epoch 1890,
# Train  loss 0.3330, precision 0.8800
# Epoch 1900,
# Train  loss 0.3327, precision 0.8800
# Epoch 1910,
# Train  loss 0.3324, precision 0.8800
# Epoch 1920,
# Train  loss 0.3321, precision 0.8800
# Epoch 1930,
# Train  loss 0.3318, precision 0.8800
# Epoch 1940,
# Train  loss 0.3314, precision 0.8800
# Epoch 1950,
# Train  loss 0.3311, precision 0.8800
# Epoch 1960,
# Train  loss 0.3308, precision 0.8800
# Epoch 1970,
# Train  loss 0.3305, precision 0.8800
# Epoch 1980,
# Train  loss 0.3302, precision 0.8800
# Epoch 1990,
# Train  loss 0.3299, precision 0.8800
# Epoch 2000,
# Train  loss 0.3295, precision 0.8800
# Epoch 2010,
# Train  loss 0.3292, precision 0.8800
# Epoch 2020,
# Train  loss 0.3289, precision 0.8800
# Epoch 2030,
# Train  loss 0.3286, precision 0.8800
# Epoch 2040,
# Train  loss 0.3283, precision 0.8800
# Epoch 2050,
# Train  loss 0.3279, precision 0.8800
# Epoch 2060,
# Train  loss 0.3276, precision 0.8800
# Epoch 2070,
# Train  loss 0.3273, precision 0.8800
# Epoch 2080,
# Train  loss 0.3270, precision 0.8800
# Epoch 2090,
# Train  loss 0.3267, precision 0.8800
# Epoch 2100,
# Train  loss 0.3263, precision 0.8800
# Epoch 2110,
# Train  loss 0.3260, precision 0.8800
# Epoch 2120,
# Train  loss 0.3257, precision 0.8800
# Epoch 2130,
# Train  loss 0.3254, precision 0.8800
# Epoch 2140,
# Train  loss 0.3251, precision 0.8800
# Epoch 2150,
# Train  loss 0.3247, precision 0.8800
# Epoch 2160,
# Train  loss 0.3244, precision 0.8800
# Epoch 2170,
# Train  loss 0.3241, precision 0.8800
# Epoch 2180,
# Train  loss 0.3238, precision 0.8800
# Epoch 2190,
# Train  loss 0.3235, precision 0.8800
# Epoch 2200,
# Train  loss 0.3231, precision 0.8800
# Epoch 2210,
# Train  loss 0.3228, precision 0.8800
# Epoch 2220,
# Train  loss 0.3225, precision 0.8800
# Epoch 2230,
# Train  loss 0.3222, precision 0.8800
# Epoch 2240,
# Train  loss 0.3219, precision 0.8800
# Epoch 2250,
# Train  loss 0.3215, precision 0.8800
# Epoch 2260,
# Train  loss 0.3212, precision 0.8800
# Epoch 2270,
# Train  loss 0.3209, precision 0.8800
# Epoch 2280,
# Train  loss 0.3206, precision 0.8800
# Epoch 2290,
# Train  loss 0.3203, precision 0.8800
# Epoch 2300,
# Train  loss 0.3199, precision 0.8800
# Epoch 2310,
# Train  loss 0.3196, precision 0.8800
# Epoch 2320,
# Train  loss 0.3193, precision 0.8800
# Epoch 2330,
# Train  loss 0.3190, precision 0.8800
# Epoch 2340,
# Train  loss 0.3187, precision 0.8800
# Epoch 2350,
# Train  loss 0.3183, precision 0.8800
# Epoch 2360,
# Train  loss 0.3180, precision 0.8800
# Epoch 2370,
# Train  loss 0.3177, precision 0.8800
# Epoch 2380,
# Train  loss 0.3174, precision 0.8800
# Epoch 2390,
# Train  loss 0.3170, precision 0.8800
# Epoch 2400,
# Train  loss 0.3167, precision 0.8800
# Epoch 2410,
# Train  loss 0.3164, precision 0.8800
# Epoch 2420,
# Train  loss 0.3161, precision 0.8800
# Epoch 2430,
# Train  loss 0.3158, precision 0.8800
# Epoch 2440,
# Train  loss 0.3154, precision 0.8800
# Epoch 2450,
# Train  loss 0.3151, precision 0.8800
# Epoch 2460,
# Train  loss 0.3148, precision 0.8800
# Epoch 2470,
# Train  loss 0.3145, precision 0.8800
# Epoch 2480,
# Train  loss 0.3141, precision 0.8800
# Epoch 2490,
# Train  loss 0.3138, precision 0.8800
# Epoch 2500,
# Train  loss 0.3135, precision 0.8800
# Epoch 2510,
# Train  loss 0.3132, precision 0.8800
# Epoch 2520,
# Train  loss 0.3128, precision 0.8800
# Epoch 2530,
# Train  loss 0.3125, precision 0.8800
# Epoch 2540,
# Train  loss 0.3122, precision 0.8800
# Epoch 2550,
# Train  loss 0.3119, precision 0.8800
# Epoch 2560,
# Train  loss 0.3115, precision 0.8800
# Epoch 2570,
# Train  loss 0.3112, precision 0.8800
# Epoch 2580,
# Train  loss 0.3109, precision 0.8800
# Epoch 2590,
# Train  loss 0.3106, precision 0.8800
# Epoch 2600,
# Train  loss 0.3102, precision 0.8800
# Epoch 2610,
# Train  loss 0.3099, precision 0.8800
# Epoch 2620,
# Train  loss 0.3096, precision 0.8800
# Epoch 2630,
# Train  loss 0.3093, precision 0.8800
# Epoch 2640,
# Train  loss 0.3089, precision 0.8800
# Epoch 2650,
# Train  loss 0.3086, precision 0.8900
# Epoch 2660,
# Train  loss 0.3083, precision 0.8900
# Epoch 2670,
# Train  loss 0.3079, precision 0.8900
# Epoch 2680,
# Train  loss 0.3076, precision 0.8900
# Epoch 2690,
# Train  loss 0.3073, precision 0.9000
# Epoch 2700,
# Train  loss 0.3070, precision 0.9000
# Epoch 2710,
# Train  loss 0.3066, precision 0.9000
# Epoch 2720,
# Train  loss 0.3063, precision 0.9000
# Epoch 2730,
# Train  loss 0.3060, precision 0.9000
# Epoch 2740,
# Train  loss 0.3057, precision 0.9000
# Epoch 2750,
# Train  loss 0.3053, precision 0.9000
# Epoch 2760,
# Train  loss 0.3050, precision 0.9000
# Epoch 2770,
# Train  loss 0.3047, precision 0.9000
# Epoch 2780,
# Train  loss 0.3043, precision 0.9000
# Epoch 2790,
# Train  loss 0.3040, precision 0.9000
# Epoch 2800,
# Train  loss 0.3037, precision 0.9000
# Epoch 2810,
# Train  loss 0.3034, precision 0.9000
# Epoch 2820,
# Train  loss 0.3030, precision 0.9000
# Epoch 2830,
# Train  loss 0.3027, precision 0.9000
# Epoch 2840,
# Train  loss 0.3024, precision 0.9000
# Epoch 2850,
# Train  loss 0.3020, precision 0.9000
# Epoch 2860,
# Train  loss 0.3017, precision 0.9000
# Epoch 2870,
# Train  loss 0.3014, precision 0.9000
# Epoch 2880,
# Train  loss 0.3011, precision 0.9000
# Epoch 2890,
# Train  loss 0.3007, precision 0.9000
# Epoch 2900,
# Train  loss 0.3004, precision 0.9000
# Epoch 2910,
# Train  loss 0.3001, precision 0.9000
# Epoch 2920,
# Train  loss 0.2997, precision 0.9000
# Epoch 2930,
# Train  loss 0.2994, precision 0.9000
# Epoch 2940,
# Train  loss 0.2991, precision 0.9000
# Epoch 2950,
# Train  loss 0.2988, precision 0.9000
# Epoch 2960,
# Train  loss 0.2984, precision 0.9000
# Epoch 2970,
# Train  loss 0.2981, precision 0.9000
# Epoch 2980,
# Train  loss 0.2978, precision 0.9000
# Epoch 2990,
# Train  loss 0.2975, precision 0.9000
# Epoch 3000,
# Train  loss 0.2971, precision 0.9000

# %% [markdown]
# ## 4. Plot result

# %%
import matplotlib.pyplot as plt

# plot the training loss and accuracy
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(2,2,(1,2))
plt.style.use("ggplot")

plt.plot(range(1, EPOCHS+1), train_loss, label="train_loss")
plt.plot(range(1, EPOCHS+1), test_loss, label="test_loss")

plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")

fig.add_subplot(2,2,(3,4))
plt.plot(range(1, EPOCHS+1), train_score, label="train_acc")
plt.plot(range(1, EPOCHS+1), test_score, label="test_acc")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="best")

plt.savefig(f'result_picture/batch{BATCH_SIZE}_epoch{EPOCHS}_train{train_score[-1]}_test{test_score[-1]}.png')


plt.show()
